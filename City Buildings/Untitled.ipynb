# %%
import matplotlib as plt
import geopandas as gpd
import os
# %matplotlib inline

# %%
cityData = gpd.read_file("citybuildings.shp")

# %%
cityData.columns
# Out:
# Index(['osm_id', 'osm_way_id', 'name', 'type', 'amenity', 'building',
#        'landuse', 'leisure', 'tourism', 'floor', 'use', 'geometry'],
#       dtype='object')

# %%
cityData.head()
# Out:
#     osm_id osm_way_id                     name          type amenity  \
# 0  1862844       None                     None  multipolygon    None
# 1  3224333       None          KenCom Building  multipolygon    None
# 2     None   40925985   InterContinental Hotel          None    None
# 3     None   78308386  Kenya National Archives          None    None
# 4     None   79418479       Education Building          None    None
#
#      building landuse leisure tourism  floor         use  \
# 0         yes    None    None    None     20  commercial
# 1  commercial    None    None    None     20  commercial
# 2         yes    None    None   hotel     20  commercial
# 3         yes    None    None  museum     20  commercial
# 4         yes    None    None    None     20  commercial
#
#                                             geometry
# 0  POLYGON ((36.8322634 -1.282298, 36.8322095 -1....
# 1  POLYGON ((36.8256099 -1.2858604, 36.8256804 -1...
# ...

# %%
cityData.tail()
# Out:
#      osm_id osm_way_id  name  type amenity building landuse leisure tourism  \
# 1935   None  700289679  None  None    None      yes    None    None    None
# 1936   None  700289680  None  None    None      yes    None    None    None
# 1937   None  700289681  None  None    None      yes    None    None    None
# 1938   None  700289682  None  None    None      yes    None    None    None
# 1939   None  700289683  None  None    None      yes    None    None    None
#
#       floor             use                                           geometry
# 1935     36  not classified  POLYGON ((36.8307228 -1.2831972, 36.8307471 -1...
# 1936     36  not classified  POLYGON ((36.830051 -1.2830322, 36.8298571 -1....
# 1937     36  not classified  POLYGON ((36.8302118 -1.283109, 36.8300736 -1....
# 1938     36  not classified  POLYGON ((36.8300869 -1.2829801, 36.8301255 -1...
# 1939     36  not classified  POLYGON ((36.8301745 -1.2827856, 36.8302168 -1...

# %%
cityData.describe()
# Out:
#              floor
# count  1940.000000
# mean     23.343299
# std       8.073009
# min      15.000000
# 25%      15.000000
# 50%      25.000000
# 75%      30.000000
# max      36.000000

# %%
cityData.plot()

# %%
cityData.plot(figsize=(20,20),facecolor="Green",column="name",legend="True")
