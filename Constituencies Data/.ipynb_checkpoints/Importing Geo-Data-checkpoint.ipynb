# %% [markdown]
# # WORKING WITH GEOGRAPHIC DATA

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
# %matplotlib inline

# %% [markdown]
# # Declaring input data

# %%
inputData = gpd.read_file("constituencies.shp")

# %% [markdown]
# # Display columns

# %%
inputData.columns
# Out:
# Index(['OBJECTID', 'COUNTY_NAM', 'CONST_CODE', 'CONSTITUEN', 'COUNTY_ASS',
#        'COUNTY_A_1', 'REGIST_CEN', 'REGISTRATI', 'COUNTY_COD', 'Shape_Leng',
#        'Shape_Area', 'geometry'],
#       dtype='object')

# %% [markdown]
# # Display top rows

# %%
inputData.head(120)
# Out:
#      OBJECTID  COUNTY_NAM  CONST_CODE         CONSTITUEN  COUNTY_ASS  \
# 0           1     NAIROBI       288.0          KAMUKUNJI         0.0
# 1           2     NAIROBI       274.0          WESTLANDS         0.0
# 2           3     NAIROBI       275.0    DAGORETTI NORTH         0.0
# 3           4     NAIROBI       279.0           ROYSAMBU         0.0
# 4           5     NAIROBI       289.0            STAREHE         0.0
# 5           6     NAIROBI       277.0            LANGATA         0.0
# 6           7     NAIROBI       276.0    DAGORETTI SOUTH         0.0
# 7           8     NAIROBI       280.0           KASARANI         0.0
# 8           9     NAIROBI       281.0            RUARAKA         0.0
# 9          10     NAIROBI       278.0              KIBRA         0.0
# 10         11     NAIROBI       290.0            MATHARE         0.0
# 11         12     MOMBASA         3.0            KISAUNI         9.0
# 12         13     MOMBASA         6.0              MVITA        27.0
# 13         14     MOMBASA         2.0              JOMVU         8.0
# 14         15     MOMBASA         4.0              NYALI        16.0
# 15         16     MOMBASA         5.0             LIKONI        21.0
# 16         17       KWALE        10.0            KINANGO        47.0
# 17         18       KWALE         9.0             MATUGA         0.0
# 18         19       KWALE         8.0        LUNGA LUNGA         0.0
# 19         20       KWALE         7.0          MSAMBWENI        31.0
# 20         21      KILIFI        13.0           KALOLENI        63.0
# 21         22      KILIFI        15.0              GANZE        74.0
# 22         23      KILIFI        11.0       KILIFI NORTH        55.0
# 23         24      KILIFI        12.0       KILIFI SOUTH        61.0
# 24         25      KILIFI        17.0           MAGARINI         0.0
# 25         26      KILIFI        14.0              RABAI        69.0
# 26         27      KILIFI        16.0            MALINDI         0.0
# 27         28  TANA RIVER        19.0             GALOLE         0.0
# 28         29  TANA RIVER        20.0               BURA         0.0
# 29         30  TANA RIVER        18.0             GARSEN        86.0
# ..        ...         ...         ...                ...         ...
# 90         91       NYERI        95.0              KIENI         0.0
# 91         92       NYERI        96.0            MATHIRA         0.0
# 92         93       NYERI        97.0             OTHAYA         0.0
# 93         94       NYERI        94.0               TETU         0.0
# 94         95       NYERI        98.0         MUKURWEINI         0.0
# 95         96       NYERI        99.0         NYERI TOWN         0.0
# 96         97   KIRINYAGA       101.0            GICHUGU         0.0
# 97         98   KIRINYAGA       103.0  KIRINYAGA CENTRAL         0.0
# 98         99   KIRINYAGA       102.0               NDIA         0.0
# 99        100   KIRINYAGA       100.0               MWEA         0.0
# 100       101    MURANG'A       105.0           MATHIOYA         0.0
# 101       102    MURANG'A       109.0            KANDARA         0.0
# 102       103    MURANG'A       108.0            MARAGWA         0.0
# 103       104    MURANG'A       104.0            KANGEMA         0.0
# 104       105    MURANG'A       107.0             KIGUMO         0.0
# 105       106    MURANG'A       106.0             KIHARU         0.0
# 106       107      KIAMBU       112.0      GATUNDU NORTH         0.0
# 107       108      KIAMBU       119.0             KABETE         0.0
# 108       109      KIAMBU       118.0            KIAMBAA         0.0
# 109       110      KIAMBU       116.0         GITHUNGURI         0.0
# 110       111      KIAMBU       114.0         THIKA TOWN         0.0
# 111       112    MURANG'A       110.0            GATANGA         0.0
# 112       113      KIAMBU       120.0             KIKUYU         0.0
# 113       114      KIAMBU       121.0             LIMURU         0.0
# 114       115      KIAMBU       111.0      GATUNDU SOUTH         0.0
# 115       116      KIAMBU       122.0               LARI         0.0
# 116       117      KIAMBU       113.0               JUJA         0.0
# 117       118      KIAMBU       115.0              RUIRU         0.0
# 118       119      KIAMBU       117.0             KIAMBU         0.0
# 119       120     TURKANA       123.0      TURKANA NORTH         0.0
#
#          COUNTY_A_1  REGIST_CEN REGISTRATI  COUNTY_COD  Shape_Leng  \
# 0              None         0.0       None        47.0    0.164632
# 1              None         0.0       None        47.0    0.412418
# 2              None         0.0       None        47.0    0.232409
# 3              None         0.0       None        47.0    0.384357
# 4              None         0.0       None        47.0    0.206915
# 5              None         0.0       None        47.0    0.855013
# 6              None         0.0       None        47.0    0.275048
# 7              None         0.0       None        47.0    0.723687
# 8              None         0.0       None        47.0    0.175183
# 9              None         0.0       None        47.0    0.207913
# 10             None         0.0       None        47.0    0.110374
# 11         MJAMBERE         0.0       None         1.0    0.526641
# 12            TUDOR         0.0       None         1.0    0.160696
# 13        MIKINDANI         0.0       None         1.0    0.354358
# 14       FRERE TOWN         0.0       None         1.0    0.204972
# 15          MTONGWE         0.0       None         1.0    0.417956
# 16   MACKINNON ROAD         0.0       None         2.0    3.862982
# 17             None         0.0       None         2.0    1.866443
# 18             None         0.0       None         2.0    2.492772
# 19   GOMBATO BONGWE         0.0       None         2.0    1.266091
# 20        MARIAKANI         0.0       None         3.0    1.394617
# 21           SOKOKE         0.0       None         3.0    2.533145
# 22       MATSANGONI         0.0       None         3.0    2.476473
# 23         CHASIMBA         0.0       None         3.0    1.024113
# 24             None         0.0       None         3.0    3.814977
# 25       KAMBE/RIBE         0.0       None         3.0    0.678199
# 26             None         0.0       None         3.0    1.665274
# 27             None         0.0       None         4.0    4.350680
# 28             None         0.0       None         4.0    4.963618
# 29      KIPINI EAST         0.0       None         4.0    6.292873
# ..              ...         ...        ...         ...         ...
# 90             None         0.0       None        19.0    2.565493
# 91             None         0.0       None        19.0    1.172050
# 92             None         0.0       None        19.0    0.969881
# 93             None         0.0       None        19.0    1.402209
# 94             None         0.0       None        19.0    0.612954
# 95             None         0.0       None        19.0    0.669607
# 96             None         0.0       None        20.0    1.021807
# 97             None         0.0       None        20.0    1.063770
# 98             None         0.0       None        20.0    1.313255
# 99             None         0.0       None        20.0    0.971302
# 100            None         0.0       None        21.0    1.174778
# 101            None         0.0       None        21.0    0.928656
# 102            None         0.0       None        21.0    1.275152
# 103            None         0.0       None        21.0    1.089141
# 104            None         0.0       None        21.0    1.325269
# 105            None         0.0       None        21.0    1.461911
# 106            None         0.0       None        22.0    0.924044
# 107            None         0.0       None        22.0    0.391225
# 108            None         0.0       None        22.0    0.459856
# 109            None         0.0       None        22.0    0.716940
# 110            None         0.0       None        22.0    1.100779
# 111            None         0.0       None        21.0    2.260314
# 112            None         0.0       None        22.0    0.692780
# 113            None         0.0       None        22.0    0.893457
# 114            None         0.0       None        22.0    0.897257
# 115            None         0.0       None        22.0    1.348804
# 116            None         0.0       None        22.0    0.933182
# 117            None         0.0       None        22.0    0.939598
# 118            None         0.0       None        22.0    0.463979
# 119            None         0.0       None        23.0    6.737283
#
#      Shape_Area                                           geometry
# 0      0.000978  POLYGON ((36.87595372679757 -1.262533413477499...
# 1      0.005909  POLYGON ((36.81926300479753 -1.206434634477475...
# 2      0.002385  POLYGON ((36.79214315479756 -1.260847108477478...
# 3      0.003908  POLYGON ((36.90578043879756 -1.161375592477484...
# 4      0.001325  POLYGON ((36.84274500879754 -1.264599326477466...
# 5      0.016950  POLYGON ((36.73136210779753 -1.303214930477495...
# 6      0.001987  POLYGON ((36.71819338479755 -1.262434261477481...
# 7      0.011069  POLYGON ((37.06335226679757 -1.205262893477468...
# 8      0.000585  POLYGON ((36.90672475279754 -1.234179657477498...
# 9      0.001080  POLYGON ((36.82186822779757 -1.295495154477508...
# 10     0.000236  POLYGON ((36.87817864879755 -1.251022484477503...
# 11     0.008339  POLYGON ((39.70052682779757 -3.923627703477494...
# 12     0.001454  POLYGON ((39.67650415579757 -4.037568951477497...
# 13     0.003585  POLYGON ((39.60383990879753 -3.956250587477471...
# 14     0.002242  POLYGON ((39.69870788279754 -4.002381201477463...
# 15     0.004847  POLYGON ((39.64474069479754 -4.060163348477475...
# 16     0.393640  POLYGON ((39.54574167079758 -3.993940203477494...
# 17     0.097592  POLYGON ((39.53115426879756 -4.076154558477513...
# 18     0.190163  POLYGON ((39.08651315579757 -4.20457252747751,...
# 19     0.076728  POLYGON ((39.56659433779756 -4.257928405477501...
# 20     0.059019  POLYGON ((39.54055368279753 -3.639753191477483...
# 21     0.238842  POLYGON ((39.75991403479755 -3.208967058477513...
# 22     0.063794  POLYGON ((40.05495797979753 -3.271222918477506...
# 23     0.032506  POLYGON ((39.77614938579753 -3.673627703477494...
# 24     0.564685  POLYGON ((40.18831979579758 -2.730268328477494...
# 25     0.016319  (POLYGON ((39.54574167079758 -3.99394020347749...
# 26     0.049598  POLYGON ((39.82833444479754 -3.115461199477509...
# 27     0.787190  POLYGON ((39.90414010879757 -1.300458758477462...
# 28     1.105004  POLYGON ((39.04775583179755 -0.007062762477503...
# 29     1.292212  POLYGON ((39.77614938579753 -1.786359637477503...
# ..          ...                                                ...
# 90     0.147247  POLYGON ((37.07851754979756 -0.000470965477505...
# 91     0.037179  POLYGON ((37.25051462079752 -0.306623308477513...
# 92     0.028934  POLYGON ((36.73195993279753 -0.487043230477511...
# 93     0.029072  POLYGON ((36.85695993279753 -0.385724871477507...
# 94     0.014462  POLYGON ((37.06051217879754 -0.518171160477479...
# 95     0.013673  (POLYGON ((37.05215036279755 -0.47373756647748...
# 96     0.037234  POLYGON ((37.43075143679757 -0.516340105477511...
# 97     0.019913  POLYGON ((37.31216360979757 -0.532815727477484...
# 98     0.018669  POLYGON ((37.21568970079758 -0.443492287477497...
# 99     0.043924  POLYGON ((37.43943076379755 -0.542194125477508...
# 100    0.018735  POLYGON ((36.74593698379757 -0.569745867477466...
# 101    0.017850  POLYGON ((36.90536081179757 -0.803327410477479...
# 102    0.037529  POLYGON ((37.15792428879754 -0.749616473477474...
# 103    0.024063  POLYGON ((36.76192819479754 -0.610944598477474...
# 104    0.024788  POLYGON ((36.72732126079753 -0.683027117477466...
# 105    0.033199  POLYGON ((37.07772409279757 -0.617231219477489...
# 106    0.019010  POLYGON ((36.66451608579754 -0.80973610147747,...
# 107    0.004762  POLYGON ((36.69165812579754 -1.181822406477509...
# 108    0.006545  POLYGON ((36.74154245279757 -1.110151140477499...
# 109    0.013997  POLYGON ((36.82113229579758 -1.018354265477499...
# 110    0.017789  POLYGON ((37.04531442479756 -1.033674090477505...
# 111    0.048768  POLYGON ((36.79055368279753 -0.779950945477467...
# 112    0.013881  POLYGON ((36.63454782379753 -1.167035906477495...
# 113    0.023095  POLYGON ((36.67513620279757 -1.071821062477497...
# 114    0.017970  POLYGON ((36.67556344879753 -0.853620379477477...
# 115    0.037820  POLYGON ((36.68795358579754 -0.764936297477491...
# 116    0.026372  POLYGON ((36.98971139779754 -1.018232195477467...
# 117    0.016409  POLYGON ((36.88875924979757 -1.099164812477497...
# 118    0.008581  POLYGON ((36.87935983579754 -1.11582741047748,...
# 119    1.668771  POLYGON ((35.63332712079752 5.371965558522517,...
#
# [120 rows x 12 columns]

# %% [markdown]
# # Displaying last rows

# %%
inputData.tail()
# Out:
#      OBJECTID COUNTY_NAM  CONST_CODE CONSTITUEN  COUNTY_ASS COUNTY_A_1  \
# 290       334       None         0.0       None         0.0       None
# 291       341       None         0.0       None         0.0       None
# 292       342       None         0.0       None         0.0       None
# 293       348       None         0.0       None         0.0       None
# 294       349       None         0.0       None         0.0       None
#
#      REGIST_CEN REGISTRATI  COUNTY_COD  Shape_Leng  Shape_Area  \
# 290         0.0       None         0.0    0.010436    0.000005
# 291         0.0       None         0.0    0.026186    0.000016
# 292         0.0       None         0.0    0.032459    0.000021
# 293         0.0       None         0.0    0.017963    0.000011
# 294         0.0       None         0.0    0.017125    0.000007
#
#                                               geometry
# 290  POLYGON ((34.75454294079756 -0.031843035477479...
# 291  POLYGON ((34.77883144179756 -0.122784271477471...
# 292  POLYGON ((34.77871286279755 -0.122846453477493...
# 293  POLYGON ((34.78615915179753 -0.113752215477505...
# 294  POLYGON ((34.78432809679756 -0.112836688477487...

# %% [markdown]
# # Data description

# %%
inputData.describe()
# Out:
#          OBJECTID  CONST_CODE  COUNTY_ASS  REGIST_CEN  COUNTY_COD  Shape_Leng  \
# count  295.000000  295.000000  295.000000       295.0  295.000000  295.000000
# mean   148.844068  143.033898    4.722034         0.0   26.067797    1.732926
# std     86.972449   85.245736   20.883806         0.0   14.092339    1.566901
# min      1.000000    0.000000    0.000000         0.0    0.000000    0.010436
# 25%     74.500000   69.500000    0.000000         0.0   15.000000    0.774398
# 50%    148.000000  143.000000    0.000000         0.0   27.000000    1.187092
# 75%    221.500000  216.500000    0.000000         0.0   39.000000    2.137293
# max    349.000000  290.000000  142.000000         0.0   47.000000    9.047598
#
#        Shape_Area
# count  295.000000
# mean     0.164129
# std      0.344195
# min      0.000005
# 25%      0.017910
# 50%      0.037751
# 75%      0.112657
# max      3.299842

# %% [markdown]
# # Plotting the data

# %%
inputData.plot()

# %% [markdown]
# # Adding size parameter to inputdata.plot() [RESIZING DATA]

# %%
inputData.plot(figsize=(10,20))

# %% [markdown]
# # Selecting data of same Column Name

# %%
nyeriCounty = inputData[inputData.COUNTY_NAM == "NYERI" ]

# %%
nyeriCounty.head(50)
# Out:
#     OBJECTID COUNTY_NAM  CONST_CODE  CONSTITUEN  COUNTY_ASS COUNTY_A_1  \
# 90        91      NYERI        95.0       KIENI         0.0       None
# 91        92      NYERI        96.0     MATHIRA         0.0       None
# 92        93      NYERI        97.0      OTHAYA         0.0       None
# 93        94      NYERI        94.0        TETU         0.0       None
# 94        95      NYERI        98.0  MUKURWEINI         0.0       None
# 95        96      NYERI        99.0  NYERI TOWN         0.0       None
#
#     REGIST_CEN REGISTRATI  COUNTY_COD  Shape_Leng  Shape_Area  \
# 90         0.0       None        19.0    2.565493    0.147247
# 91         0.0       None        19.0    1.172050    0.037179
# 92         0.0       None        19.0    0.969881    0.028934
# 93         0.0       None        19.0    1.402209    0.029072
# 94         0.0       None        19.0    0.612954    0.014462
# 95         0.0       None        19.0    0.669607    0.013673
#
#                                              geometry
# 90  POLYGON ((37.07851754979756 -0.000470965477505...
# 91  POLYGON ((37.25051462079752 -0.306623308477513...
# 92  POLYGON ((36.73195993279753 -0.487043230477511...
# 93  POLYGON ((36.85695993279753 -0.385724871477507...
# 94  POLYGON ((37.06051217879754 -0.518171160477479...
# 95  (POLYGON ((37.05215036279755 -0.47373756647748...

# %%
nyeriCounty.plot(figsize=(10,20))

# %%
nyeriCounty = inputData[inputData.COUNTY_COD == 19.0 ].plot()

# %% [markdown]
# # Working with multiple layers in one dataframe

# %%
townsData = gpd.read_file("kenya_all_towns.shp")

# %%
townsData.plot(figsize=(10,20))

# %% [markdown]
# Defining Varibles to be used:

# %%
fifg, ax = plt.subplots(figsize = (10,10))
inputData.plot(ax = ax, facecolor = "Grey")
townsData.plot(ax = ax, markersize = 2, facecolor = "Gold")
